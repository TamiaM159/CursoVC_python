# %%
Deber 1

# %%
Tamia Muñoz

# %%
# importar la libreria de VC
import cv2 as cv
import matplotlib.pyplot as plt
# lctura de una imagen
img = cv.imread("img.jpg")
# mostrar la imagen
plt.imshow(img)

# %% [markdown]
# 2.1.3 cv.IMREAD_GRAYSCALE

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread("img.jpg", cv.IMREAD_GRAYSCALE)
plt.imshow(img, cmap="gray")

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread("img.jpg", cv.IMREAD_COLOR)
plt.imshow(img, cmap="gray")

# %%
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# Ventana emergente

# %%
import cv2 as cv
#leemos la imagen
img = cv.imread("img.jpg")
cv.imshow("Copa", img)
# cerramos la imagen
cv.waitKey(0)
cv.destroyAllWindows()

# %% [raw]
# Guardar imagen

# %%
import cv2 as cv
img = cv.imread("img.jpg")
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imwrite("img2.jpg", img_gray)
# Out:
# True

# %% [markdown]
# Reproducir video desde archivo

# %%
import numpy as np
import cv2 as cv

# crear un objeto VideoCapture su parametro sera la direccion del video
cap = cv.VideoCapture("video.mp4")
# creamos un bucle

while(cap.isOpened()):
    
    ret,frame = cap.read()
    if ret:
        
        cv.imshow("TM", frame)
        if(cv.waitKey(10) & 0xFF ==ord("q")):
            break
    else:
        break
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# Acceder a la camara

# %%
import numpy as np
import cv2 as cv

# crear un objeto VideoCapture su parametro sera la direccion del video
cap = cv.VideoCapture(0)
# creamos un bucle

while(cap.isOpened()):

    ret,frame = cap.read()
    if ret:
        cv.imshow("Camara WEb", frame)
        if(cv.waitKey(10) & 0xFF ==ord("q")):
            break
    else:
        break
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# Función para Dibujar Geometrias en OpenCV
# Dibujar linea

# %%
# la funcion cv.line()

import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# crear una imagen
img = np.zeros((600,700,3), np.uint8)
# dibujamos la linea en la imagen
cv.line(img,(100,150),(450,450),(255,0,0),6)
# mostrar la imagen
plt.imshow(img)

# %% [markdown]
# Dibujar circulo

# %%
# la funcion cv.circle()
# Parametros: img, condenadas centrales, radio, color, grosor)
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# crear una imagen
img = np.zeros((520,640,3), np.uint8)
# dibujamos circulo
cv.circle(img,(300,250), 100,(255,0,100),-1)
#mostrar nuestra imagen
plt.imshow(img)

# %% [markdown]
# Dibujar rectangulo

# %%
# la funcion cv.rectangle()
# Parametros: img, cordenada esquina superir izquierda, cordenada de la esquina␣
#,→inferior derecha, color, grosor)
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# crear una imagen
img = np.zeros((520,640,3), np.uint8)
# dibujamos circulo
cv.rectangle(img,(50,100), (450,450),(0,255,0),5)
#mostrar nuestra imagen
plt.imshow(img)

# %% [markdown]
# Captura de eventos desde el mouse

# %%
import cv2 as cv

clicked = False

# funcion encargada de capturar el click del mouse
def onMouse(evento,x,y,flags,param):
    # variable global
    global clicked
    if(evento ==cv.EVENT_LBUTTONUP):
        clicked =True
# creamos objeto cv.VideoCapture()
camCap = cv.VideoCapture(0)
cv.namedWindow("MyWindow")
# configuramos se envie a la funcion onMouse los eventos del mouse
cv.setMouseCallback("MyWindow",onMouse)
print("Mostrando estado de la Camara, Presione en la Ventana para detener")
ret,frame = camCap.read()
while(ret and cv.waitKey(1)==-1 and not clicked):
    cv.imshow("MyWindow", frame)
    ret,frame = camCap.read()
camCap.release()
cv.destroyAllWindows()
# Out:
# Mostrando estado de la Camara, Presione en la Ventana para detener

# %%
import cv2 as cv
events = [i for i in dir(cv) if 'EVENT' in i ]
events
# Out:
# ['EVENT_FLAG_ALTKEY',
#  'EVENT_FLAG_CTRLKEY',
#  'EVENT_FLAG_LBUTTON',
#  'EVENT_FLAG_MBUTTON',
#  'EVENT_FLAG_RBUTTON',
#  'EVENT_FLAG_SHIFTKEY',
#  'EVENT_LBUTTONDBLCLK',
#  'EVENT_LBUTTONDOWN',
#  'EVENT_LBUTTONUP',
#  'EVENT_MBUTTONDBLCLK',
#  'EVENT_MBUTTONDOWN',
#  'EVENT_MBUTTONUP',
#  'EVENT_MOUSEHWHEEL',
#  'EVENT_MOUSEMOVE',
#  'EVENT_MOUSEWHEEL',
#  'EVENT_RBUTTONDBLCLK',
#  'EVENT_RBUTTONDOWN',
#  'EVENT_RBUTTONUP']

# %% [markdown]
# Ejemplo: Uso de eventos con el ratón

# %%
import numpy as np
import cv2 as cv
def draw_circle(event, x, y, flags, param):
    if(event == cv.EVENT_LBUTTONDBLCLK):
        cv.circle(img, (x, y), 25, (255,0,0), -1 )
img = np.zeros((512,512,3), np.uint8)
cv.namedWindow('Dibujando Circulos')
cv.setMouseCallback('Dibujando Circulos', draw_circle)
while(True):
    cv.imshow('Dibujando Circulos',img)
    if (cv.waitKey(1) & 0xFF ==ord('t')):
        break
cv.destroyAllWindows()

# %% [markdown]
# DEBER

# %%
import numpy as np
import cv2 as cv
def draw_circle_rectangule(event, x, y, flags, param):
    if(event == cv.EVENT_LBUTTONDBLCLK):
        cv.circle(img, (x, y), 25, (255,0,0), -1 )
        
    elif(event == cv.EVENT_RBUTTONDBLCLK):
        cv.rectangle(img, (x, y), (x+50, y+50), (255,255,0), 2 )
img = np.zeros((600,600,3), np.uint8)
cv.namedWindow('Dibujos')
cv.setMouseCallback('Dibujos', draw_circle_rectangule)
while(True):
    cv.imshow('Dibujos',img)
    if (cv.waitKey(1) & 0xFF ==ord('t')):
        break
cv.destroyAllWindows()

# %% [markdown]
# Evidencia

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Lectura de una imagen
img = cv.imread("Deber1.png")

# Mostrar imagen
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
